# %% [markdown]
# ### 潜在的意味論
# 前提：同じ文脈で出現する語は同じような意味を持つというハリスの分布仮説
# 手法：文脈を統計的に分析して意味情報を抽出
# アルゴリズム例：LSI(=LSA), pLSI, LDA, など
# パッケージ：gensim
# クラス：dictionaryとcorpusは必須

# %%
# -*- coding: utf-8 -*-
# リスト 5-15　 安倍首相所信表明演説の段落間LSI類似度をグラフと樹形図に表示する
import numpy as np
import re, itertools, MeCab
from collections import defaultdict
from gensim import corpora, models, similarities
from pprint import pprint
from igraph import *

# %%
def readin(filename):
    with open(filename, "r", encoding="utf-8") as afile:
        whole_str = afile.read()
    sentenses = (re.sub('。', '', whole_str)).splitlines()
    return [re.sub('　', '', u) for u in sentenses if len(u)!=0]
num_topics = 10
m = MeCab.Tagger("-Ochasen")  # MeCabで品詞分解する
filename = "abe.txt"
string = readin(filename)

# %%
# 文単位で形態素解析し、基本形を文ごとのリストにする
sentensewordlist = [ \
    [v.split()[2] for v in m.parse(sentense).splitlines()  \
    if (len(v.split()) >=3 and v.split()[3][:2] in ['名詞','動詞','形容詞', \
                                                    '形容動詞','副詞'])] \
    for sentense in string]
# 各パラグラフの先頭文字（図でパラグラフを示すときに使う）
headlist = [ \
    sentense[2:6] if sentense[0] in ['一', '二', '三', '四', '五', '六', '七', '八', \
                                     '九', '十'] else 
    sentense[1:5] if sentense[0] in ['　', '（', '「'] else sentense[:4] \
       for sentense in string]
stoplist = {'が', 'は', 'に', 'も', 'の', 'を', 'へ', 'と', 'で', 'や', 'ば', \
 'だ', 'て', '一', '二', '三', '四', '五', '六', '七', '八', '九', '十', \
 '〇', '（', '）', '＊', '「', '」', '、', '。', 'ます', 'ある', 'こと', 'する', \
 'など', 'です', 'た', 'たち', 'その', '的', 'ため', 'いる', 'できる', 'れる', \
 'これ', 'なる', '化', ')', '(', '年', '円', '万'}
# stoplistに含まれる語を取り除く
texts = [[word for word in doc if word not in stoplist] for doc in \
         sentensewordlist]
# N回以上現れる語のみを拾う
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1
texts = [[token for token in text if frequency[token] >= 3] for text in texts]

# %%
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
# TF-IDFの計算
tfidf = models.TfidfModel(corpus) # step 1 -- initialize a model
corpus_tfidf = tfidf[corpus]
# LSIモデルクラスのインスタンス生成。corpus_tfidfを入力、トピック数をnum_topicsに設定
lsi = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=num_topics)
corpus_lsi = lsi[corpus_tfidf] # corpus_tfidfを処理

# %%
ttlist = []
# lsi.show_topicsの出力を整形して表示
for t in lsi.show_topics(num_topics, formatted=False):
    tnum = t[0]
    tlist = sorted(t[1], key=lambda u: u[1], reverse=True)[:3]
    ttlist.append( [u[0] for u in tlist] )
    print(tnum, end='  ')
    for u in tlist:   print(u[0], "%.4f" % u[1], end='   ')
    print()
# Out:
# 0  壁 -0.1223   拓く -0.1259   平和 -0.1308
# 1  創る 0.3555   未来 0.3045   国 0.2610
# 2  人 0.4784   観光 0.2804   壁 0.1867
# 3  平和 0.3164   地域 0.2279   世界 0.1761
# 4  創る 0.2391   成長 0.2119   国 0.1987
# 5  改革 0.3195   方 0.1786   働く 0.1606
# 6  ハマグリ 0.3721   兼山 0.2248   けんざん 0.2248
# 7  地方 0.3580   生 0.2132   創 0.2126
# 8  日本 0.2752   壁 0.1580   前 0.1456
# 9  方 0.1593   働く 0.1439   関係 0.1405

# %%
# corpus_lsiの内容を整形して表示
for i, doc in enumerate(corpus_lsi):
    x = [ sorted(doc, key=lambda u: u[1], reverse=True) for u in doc if len(u)!=0]
    if len(x)!=0:
        print(headlist[i], end='  ')  # 段落番号の代わりにheadlistを使って表示
        for u in x[0][:3]:
            if (u[1] >= 0.1):
                print(ttlist[u[0]], np.round(u[1],3), end=' ')
        print()
    print('---')
# Out:
# まず冒頭  ['平和', '地域', '世界'] 0.113
# ---
# ---
# 昨年末、  ['地方', '生', '創'] 0.109
# ---
# 我が国で
# ---
# 明治維新  ['日本', '壁', '前'] 0.212
# ---
# しかし、  ['創る', '未来', '国'] 0.292 ['ハマグリ', '兼山', 'けんざん'] 0.101
# ---
# 戦後七十  ['ハマグリ', '兼山', 'けんざん'] 0.183
# ---
# 少子高齢  ['創る', '未来', '国'] 0.278 ['創る', '成長', '国'] 0.127
# ---
# 私たちの  ['創る', '未来', '国'] 0.33 ['ハマグリ', '兼山', 'けんざん'] 0.189 ['方', '働く', '関係'] 0.188
# ---
# 界の真ん  ['創る', '未来', '国'] 0.32 ['創る', '成長', '国'] 0.166
# ---
# 日米同盟  ['平和', '地域', '世界'] 0.2
# ---
# かつて敵  ['創る', '未来', '国'] 0.141 ['日本', '壁', '前'] 0.104 ['平和', '地域', '世界'] 0.103
# ---
# 世界では  ['平和', '地域', '世界'] 0.397 ['改革', '方', '働く'] 0.154 ['日本', '壁', '前'] 0.131
# ---
# これまで  ['平和', '地域', '世界'] 0.265
# ---
# 先月、北
# ---
# 更に、学  ['平和', '地域', '世界'] 0.108
# ---
# かつて、  ['ハマグリ', '兼山', 'けんざん'] 0.155
# ---
# 安倍内閣  ['日本', '壁', '前'] 0.138 ['平和', '地域', '世界'] 0.101
# ---
# 地球儀を
# ---
# 本年は、
# ---
# 自由、民  ['地方', '生', '創'] 0.107 ['平和', '地域', '世界'] 0.103
# ---
# ＡＳＥＡ  ['平和', '地域', '世界'] 0.37 ['方', '働く', '関係'] 0.179 ['改革', '方', '働く'] 0.121
# ---
# 自由貿易  ['地方', '生', '創'] 0.124
# ---
# ＴＰＰ協  ['平和', '地域', '世界'] 0.18
# ---
# 継続こそ  ['平和', '地域', '世界'] 0.325 ['改革', '方', '働く'] 0.123
# ---
# 近隣諸国  ['平和', '地域', '世界'] 0.247 ['方', '働く', '関係'] 0.202
# ---
# 日本海か  ['平和', '地域', '世界'] 0.443 ['方', '働く', '関係'] 0.222 ['改革', '方', '働く'] 0.138
# ---
# ロシアと  ['平和', '地域', '世界'] 0.296 ['方', '働く', '関係'] 0.24 ['改革', '方', '働く'] 0.119
# ---
# 先月、訪  ['地方', '生', '創'] 0.194 ['平和', '地域', '世界'] 0.188 ['方', '働く', '関係'] 0.108
# ---
# この機運  ['平和', '地域', '世界'] 0.185 ['方', '働く', '関係'] 0.173 ['地方', '生', '創'] 0.116
# ---
# 本年、日  ['平和', '地域', '世界'] 0.331
# ---
# 韓国は、  ['方', '働く', '関係'] 0.144 ['平和', '地域', '世界'] 0.114
# ---
# 中国の平  ['平和', '地域', '世界'] 0.453 ['方', '働く', '関係'] 0.179 ['改革', '方', '働く'] 0.129
# ---
# 北朝鮮が  ['方', '働く', '関係'] 0.202 ['地方', '生', '創'] 0.165 ['平和', '地域', '世界'] 0.116
# ---
# 積極的平  ['平和', '地域', '世界'] 0.266
# ---
# 真新しい
# ---
# 南スーダ  ['平和', '地域', '世界'] 0.109
# ---
# その会場  ['日本', '壁', '前'] 0.219 ['人', '観光', '壁'] 0.133
# ---
# 最終日、
# ---
# 幼い息子  ['人', '観光', '壁'] 0.223
# ---
# 毎日、ス  ['平和', '地域', '世界'] 0.207 ['創る', '成長', '国'] 0.124 ['創る', '未来', '国'] 0.105
# ---
# 隊員たち  ['創る', '成長', '国'] 0.151 ['創る', '未来', '国'] 0.14 ['平和', '地域', '世界'] 0.137
# ---
# 灼熱（し  ['改革', '方', '働く'] 0.152 ['日本', '壁', '前'] 0.124 ['平和', '地域', '世界'] 0.1
# ---
# 平和のた  ['日本', '壁', '前'] 0.208 ['平和', '地域', '世界'] 0.183
# ---
# テロ、難  ['平和', '地域', '世界'] 0.381 ['日本', '壁', '前'] 0.164 ['改革', '方', '働く'] 0.144
# ---
# 強く成長  ['創る', '成長', '国'] 0.357 ['創る', '未来', '国'] 0.305 ['人', '観光', '壁'] 0.151
# ---
# 「壁」へ  ['人', '観光', '壁'] 0.185 ['日本', '壁', '前'] 0.151
# ---
# 昨年、大
# ---
# 未来は『  ['創る', '未来', '国'] 0.468 ['創る', '成長', '国'] 0.143 ['人', '観光', '壁'] 0.137
# ---
# ノーベル
# ---
# 前、日本  ['日本', '壁', '前'] 0.33 ['創る', '未来', '国'] 0.16 ['人', '観光', '壁'] 0.114
# ---
# まさにデ  ['人', '観光', '壁'] 0.203 ['日本', '壁', '前'] 0.201 ['創る', '成長', '国'] 0.137
# ---
# しかし、  ['人', '観光', '壁'] 0.236 ['日本', '壁', '前'] 0.226 ['創る', '成長', '国'] 0.191
# ---
# その結果  ['創る', '成長', '国'] 0.317 ['ハマグリ', '兼山', 'けんざん'] 0.221 ['日本', '壁', '前'] 0.175
# ---
# 長らく言  ['日本', '壁', '前'] 0.201 ['ハマグリ', '兼山', 'けんざん'] 0.138
# ---
# 格差を示  ['日本', '壁', '前'] 0.153
# ---
# 出来ない  ['日本', '壁', '前'] 0.172 ['ハマグリ', '兼山', 'けんざん'] 0.129
# ---
# この「経  ['日本', '壁', '前'] 0.273 ['ハマグリ', '兼山', 'けんざん'] 0.118
# ---
# 中小・小  ['創る', '成長', '国'] 0.346 ['ハマグリ', '兼山', 'けんざん'] 0.282
# ---
# 景気回復  ['創る', '成長', '国'] 0.292 ['ハマグリ', '兼山', 'けんざん'] 0.275
# ---
# 先月、五
# ---
# から、成  ['創る', '成長', '国'] 0.3 ['ハマグリ', '兼山', 'けんざん'] 0.229
# ---
# 生産性向
# ---
# 地方創生  ['地方', '生', '創'] 0.434
# ---
# 平均、二  ['人', '観光', '壁'] 0.31 ['改革', '方', '働く'] 0.137
# ---
# 地場の繊
# ---
# まさに「  ['人', '観光', '壁'] 0.504 ['方', '働く', '関係'] 0.165 ['改革', '方', '働く'] 0.109
# ---
# 地方には  ['地方', '生', '創'] 0.241 ['人', '観光', '壁'] 0.164
# ---
# 自分たち  ['地方', '生', '創'] 0.539 ['ハマグリ', '兼山', 'けんざん'] 0.191
# ---
# 地方の発  ['地方', '生', '創'] 0.268 ['改革', '方', '働く'] 0.158
# ---
# 故郷（ふ  ['地方', '生', '創'] 0.437
# ---
# 観光立国  ['人', '観光', '壁'] 0.28 ['方', '働く', '関係'] 0.114
# ---
# 万人の「  ['人', '観光', '壁'] 0.604
# ---
# 安倍内閣  ['人', '観光', '壁'] 0.342 ['日本', '壁', '前'] 0.175
# ---
# 日本を訪
# ---
# 民間資金
# ---
# 沖縄はア  ['人', '観光', '壁'] 0.342 ['方', '働く', '関係'] 0.153 ['地方', '生', '創'] 0.105
# ---
# 全国の地  ['地方', '生', '創'] 0.116
# ---
# いわゆる
# ---
# あらゆる  ['人', '観光', '壁'] 0.341
# ---
# 農政新時  ['ハマグリ', '兼山', 'けんざん'] 0.138 ['改革', '方', '働く'] 0.123 ['方', '働く', '関係'] 0.108
# ---
# 地方経済  ['地方', '生', '創'] 0.213 ['人', '観光', '壁'] 0.133 ['日本', '壁', '前'] 0.103
# ---
# しかし、  ['人', '観光', '壁'] 0.191
# ---
# 更なる弾  ['改革', '方', '働く'] 0.28 ['方', '働く', '関係'] 0.101
# ---
# 農業版の
# ---
# 牛乳や乳
# ---
# 農地バン  ['平和', '地域', '世界'] 0.171
# ---
# 農政改革  ['方', '働く', '関係'] 0.207 ['改革', '方', '働く'] 0.147 ['ハマグリ', '兼山', 'けんざん'] 0.138
# ---
# イノベー  ['改革', '方', '働く'] 0.259
# ---
# チャレン  ['日本', '壁', '前'] 0.2 ['改革', '方', '働く'] 0.169 ['創る', '成長', '国'] 0.124
# ---
# 医療情報  ['地方', '生', '創'] 0.114
# ---
# 人工知能  ['地方', '生', '創'] 0.138
# ---
# 民間の視  ['改革', '方', '働く'] 0.166
# ---
# 本年四月  ['地方', '生', '創'] 0.11
# ---
# 水素エネ  ['改革', '方', '働く'] 0.135
# ---
# 二〇年に  ['改革', '方', '働く'] 0.134
# ---
# 全・安心  ['創る', '未来', '国'] 0.368 ['創る', '成長', '国'] 0.283 ['人', '観光', '壁'] 0.106
# ---
# 被災地の
# ---
# 再生可能
# ---
# 南相馬で  ['ハマグリ', '兼山', 'けんざん'] 0.105
# ---
# 南相馬が  ['ハマグリ', '兼山', 'けんざん'] 0.115 ['平和', '地域', '世界'] 0.101
# ---
# 原発事故  ['平和', '地域', '世界'] 0.22 ['改革', '方', '働く'] 0.109
# ---
# 福島復興
# ---
# 今年度中
# ---
# 東北三県
# ---
# 熊本地震
# ---
# ---
# 昨年の台  ['創る', '成長', '国'] 0.106
# ---
# 水防法を  ['方', '働く', '関係'] 0.109 ['創る', '成長', '国'] 0.101
# ---
# 治水対策
# ---
# 生活の安
# ---
# 糸魚川の  ['創る', '成長', '国'] 0.149 ['平和', '地域', '世界'] 0.109
# ---
# お年寄り
# ---
# 後に迫っ
# ---
# 昨年七月
# ---
# 億総活躍  ['創る', '未来', '国'] 0.381 ['創る', '成長', '国'] 0.224 ['人', '観光', '壁'] 0.139
# ---
# 障害や難  ['方', '働く', '関係'] 0.134 ['改革', '方', '働く'] 0.113
# ---
# 総活躍の  ['創る', '未来', '国'] 0.244 ['地方', '生', '創'] 0.178
# ---
# しかし、  ['人', '観光', '壁'] 0.172
# ---
# 働き方改  ['改革', '方', '働く'] 0.354 ['方', '働く', '関係'] 0.236 ['日本', '壁', '前'] 0.149
# ---
# 最大のチ  ['改革', '方', '働く'] 0.291 ['方', '働く', '関係'] 0.176
# ---
# アベノミ
# ---
# 雇用情勢  ['改革', '方', '働く'] 0.313 ['方', '働く', '関係'] 0.136 ['日本', '壁', '前'] 0.109
# ---
# 同一労働
# ---
# 余り前、
# ---
# 抽象的な  ['方', '働く', '関係'] 0.181
# ---
# 女性の活
# ---
# 人は、幾  ['人', '観光', '壁'] 0.304 ['方', '働く', '関係'] 0.126 ['改革', '方', '働く'] 0.109
# ---
# 年間子育
# ---
# 子育ての
# ---
# 子育てや
# ---
# 百三万円  ['日本', '壁', '前'] 0.172 ['創る', '成長', '国'] 0.101
# ---
# 出産など
# ---
# 成長と分  ['創る', '成長', '国'] 0.253 ['日本', '壁', '前'] 0.175
# ---
# 保育や介
# ---
# 子育てを  ['地方', '生', '創'] 0.111
# ---
# 待機児童
# ---
# 人材を確  ['方', '働く', '関係'] 0.104
# ---
# 加えて、  ['方', '働く', '関係'] 0.14 ['日本', '壁', '前'] 0.108
# ---
# 年金受給
# ---
# 来年度予  ['創る', '成長', '国'] 0.279 ['人', '観光', '壁'] 0.151
# ---
# 同時に、  ['改革', '方', '働く'] 0.156
# ---
# 薬価制度  ['方', '働く', '関係'] 0.118
# ---
# 累次の改
# ---
# どもたち  ['創る', '未来', '国'] 0.379
# ---
# 個性を大
# ---
# 我が国の  ['創る', '未来', '国'] 0.158 ['地方', '生', '創'] 0.122
# ---
# 子どもた
# ---
# 先般成立
# ---
# 実践的な
# ---
# 誰にでも
# ---
# 邑(むら  ['人', '観光', '壁'] 0.478 ['方', '働く', '関係'] 0.132 ['改革', '方', '働く'] 0.129
# ---
# 明治日本  ['日本', '壁', '前'] 0.328
# ---
# それから  ['日本', '壁', '前'] 0.139
# ---
# 本年は、
# ---
# この七十  ['日本', '壁', '前'] 0.112
# ---
# 学問は身
# ---
# どんなに
# ---
# 高校生へ
# ---
# 更に、返
# ---
# 幼児教育
# ---
# 全ての子  ['創る', '未来', '国'] 0.303 ['地方', '生', '創'] 0.193 ['方', '働く', '関係'] 0.13
# ---
# ---
# 子や孫の  ['ハマグリ', '兼山', 'けんざん'] 0.338 ['創る', '未来', '国'] 0.302 ['方', '働く', '関係'] 0.201
# ---
# 土佐湾で  ['ハマグリ', '兼山', 'けんざん'] 0.486 ['改革', '方', '働く'] 0.199
# ---
# 美味しい  ['ハマグリ', '兼山', 'けんざん'] 0.372 ['改革', '方', '働く'] 0.133
# ---
# 兼山(け  ['ハマグリ', '兼山', 'けんざん'] 0.423 ['人', '観光', '壁'] 0.225 ['改革', '方', '働く'] 0.185
# ---
# このハマ  ['ハマグリ', '兼山', 'けんざん'] 0.406 ['創る', '未来', '国'] 0.107
# ---
# 兼山(け  ['ハマグリ', '兼山', 'けんざん'] 0.429 ['改革', '方', '働く'] 0.241 ['人', '観光', '壁'] 0.106
# ---
# まさに「  ['地方', '生', '創'] 0.273 ['創る', '未来', '国'] 0.202 ['ハマグリ', '兼山', 'けんざん'] 0.195
# ---
# 未来は変  ['地方', '生', '創'] 0.25 ['ハマグリ', '兼山', 'けんざん'] 0.218 ['方', '働く', '関係'] 0.177
# ---
# ただ批判
# ---
# 自らの未  ['地方', '生', '創'] 0.211 ['ハマグリ', '兼山', 'けんざん'] 0.166 ['創る', '未来', '国'] 0.127
# ---
# 憲法施行  ['創る', '未来', '国'] 0.266 ['ハマグリ', '兼山', 'けんざん'] 0.166 ['方', '働く', '関係'] 0.147
# ---
# 未来を拓  ['地方', '生', '創'] 0.18 ['ハマグリ', '兼山', 'けんざん'] 0.176 ['創る', '未来', '国'] 0.161
# ---
# 世界の真  ['創る', '未来', '国'] 0.368 ['日本', '壁', '前'] 0.136
# ---
# ---

# %%
# lsi[corpus]の類似度を計算
index = similarities.MatrixSimilarity(lsi[corpus]) 
# 類似度を行列に成形
simmatrix = []
for doc in texts:
    doc = ' '.join(doc)
    vec_bow = dictionary.doc2bow(doc.split())
    vec_lsi = lsi[vec_bow]  # convert the query to LSI space
    sims = index[vec_lsi]   # 元のコーパスの文に対して類似度を計算
    simmatrix.append(sims)

# igraphによるグラフ化
minsim = 0.85
edges = []
vertices = headlist         # グラフの頂点はheadlistの文字列
for i, u in enumerate(simmatrix):
    for j, v in enumerate(u):
        if v >= minsim and i!=j:  # 値がminsim以上で、対角要素でなければ、辺行列に入れる
            edges.append([i, j])
g = Graph(vertex_attrs={"label": vertices}, edges=edges, directed=False)
plot(g, vertex_size=35, vertex_label_size=9, bbox=(700,800), vertex_color='white')

# %%
# 類似度マトリックス（＝距離マトリックス）からデンドログラムへ出力
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
Z = linkage(simmatrix, 'ward')  # Ward法で階層化クラスタリング
dendrogram(                     # デンドログラムを描く
    Z,
    leaf_rotation=90.,          # x軸ラベルを90度回転
    leaf_font_size=8.,          # x軸ラベルのフォントを8ポイントにする
    labels=np.array(headlist),  # データラベルをheadlistから引用
)

plt.show()
